# %%
pip install forked-rompy
# Out:
# ...
#      |████████████████████████████████| 40 kB 234 kB/s eta 0:00:011
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import rompy as rp

# %%
help(rp.greedy)
# Out:
# Help on module rompy.greedy in rompy:
#
# NAME
#     rompy.greedy - Classes for building reduced basis greedy algorithms
#
# CLASSES
#     builtins.object
#         CrossValidation
#     _IteratedModifiedGramSchmidt(builtins.object)
#         GramSchmidt
#         ReducedBasis(_ReducedBasis, _IteratedModifiedGramSchmidt)
#     _ReducedBasis(builtins.object)
#         ReducedBasis(_ReducedBasis, _IteratedModifiedGramSchmidt)
#
#     class CrossValidation(builtins.object)
#      |  CrossValidation(**options)
#      |
#      |  Methods defined here:
#      |
#      |  Kfold(self, training, name, K=10, parallel=True, random=True)
#      |      K-fold cross-validation
#      |
#      |  Kfold_ensemble(self, x, y, n, K=10, parallel=True, random=True, verbose=False)
#      |      Perform a number n of K-fold cross-validations
#      |
#      |  LOOCV(self, x, y, parallel=True, random=True)
#      |      Leave-one-out cross-validation
#      |
# ...

# %%
pip install manimlib
# Out:
# ...
#      |████████████████████████████████| 4.8 MB 5.1 MB/s eta 0:00:01
# ...
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# ...
#      |████████████████████████████████| 205 kB 481 kB/s eta 0:00:01
# ...
#   Created wheel for manimlib: filename=manimlib-0.1.11-py3-none-any.whl size=212147 sha256=3ae959c4e07006d8d780a5c6a3e86651b2819c8c4166fc8e942ebd1f87289c6f
#   Stored in directory: /Users/zhonghaowen/Library/Caches/pip/wheels/8d/95/10/2a36942dc5dacfa78b60d925bd618103822f153b377b233b67
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12074 sha256=757ed7d2a50ef5556eab204c1625b4a92e6bdb28e3b12d09240d790ef39cec96
#   Stored in directory: /Users/zhonghaowen/Library/Caches/pip/wheels/f0/fd/1f/3e35ed57e94cd8ced38dd46771f1f0f94f65fec548659ed855
# ...
#   ERROR: Command errored out with exit status 1:
# ...
